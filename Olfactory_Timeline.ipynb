# %% [markdown]
# <a href="https://colab.research.google.com/github/lneal5/Fragrance-Trends-V1/blob/main/Olfactory_Timeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1920-1929 https://www.fragrantica.com/search/?godina=1920%3A1929

import requests
from bs4 import BeautifulSoup

url = 'https://www.fragrantica.com/search/?godina=1920%3A1929'

headers = {
    'authority': 'csm.us.criteo.net',
    'sec-ch-ua': '"Chromium";v="94", "Google Chrome";v="94", ";Not A Brand";v="99"',
    'dnt': '1',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 14150.87.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.124 Safari/537.36',
    'sec-ch-ua-platform': '"Chrome OS"',
    'content-type': 'text/plain;charset=UTF-8',
    'accept': '*/*',
    'origin': 'https://ads.us.criteo.com',
    'sec-fetch-site': 'cross-site',
    'sec-fetch-mode': 'no-cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://ads.us.criteo.com/',
    'accept-language': 'en-US,en;q=0.9',
}

results = requests.get(url, headers=headers)

soup = BeautifulSoup(results.text,'html.parser')

parent_div = soup.findAll('div',{'class':'card-section'})

print(parent_div)
# Out:
# [<div class="card-section">
# <img alt="perfume Coco Mademoiselle" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.611.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Chanel/Coco-Mademoiselle-611.html"> Chanel Coco Mademoiselle
# <span aria-label="Link to Chanel Coco Mademoiselle female 2001" class="link-span" title="Chanel Coco Mademoiselle female 2001"></span></a></p>
# </div>, <div class="card-section">
# <img alt="perfume La Nuit de l'Homme" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.5521.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Yves-Saint-Laurent/La-Nuit-de-l-Homme-5521.html"> Yves Saint Laurent La Nuit de l'Homme
# <span aria-label="Link to Yves Saint Laurent La Nuit de l'Homme male 2009" class="link-span" title="Yves Saint Laurent La Nuit de l'Homme male 2009"></span></a></p>
# </div>, <div class="card-section">
# ...

# %%
  #1930-1939 https://www.fragrantica.com/search/?godina=1930%3A1939

import requests
from bs4 import BeautifulSoup

url = 'https://www.fragrantica.com/search/?godina=1930%3A1939'

headers = {
    'authority': 'www.fragrantica.com',
    'sec-ch-ua': '"Chromium";v="94", "Google Chrome";v="94", ";Not A Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Chrome OS"',
    'dnt': '1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 14150.87.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.124 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'none',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': '__auc=0bc2fd9a17cdd73ef4db3b0e514; set_invisible=visible; _gid=GA1.2.260011367.1639937338; frecently=a%3A1%3A%7Bi%3A28711%3Bi%3A1639954575%3B%7D; __cf_bm=JyCU24FUM6sMdLM.o0VASsvnosR0C0V0n8FuibVqnd0-1640025569-0-ARgZZ4pKRsO/9RU/Wt8p/7NPSCzVo6tkh9Mlr+wEEynJZgzEPN4fBm8BrDc7EkZHaZGp7jGU+NlI4lgTml7x6IZ9guIURz6144SC9gHz4urtWu/S8Xy8hOwQHKJkhW2auA==; __asc=e4e5971d17dd92457d9871a12a8; fragrantica_com_555=MTQwODk0N3w5MmM4ZGY4MzAwMmUyZjQ1ZGE2MTExZmE2YmNiZjVlZGU3M2ZlMmZhfDE2NDEyMzU0Mzd8ZDcwMGMyN2JiNjA3ZDdlMjI4N2I5MDRkMGUyMjE1YWJlNmY1ZTg5NA%3D%3D; rtyt45gh=16; _ga_LKTF6586LY=GS1.1.1640025572.13.1.1640025838.0; _ga=GA1.2.420026503.1639438000; cto_bundle=gTWE7F9hdWRqSWxTM3VvZVQwNWhUTFg2alJteWNzN3JvQjM5SnhQZXdaWkpybktsc21XN1d1TzRLc0RxNlM3NEMyJTJCSk9PWk1XTFpHb0pzTFFwenV2Z1pWWlRrVlcyNVJpNndsZHFWdWZGUzFRNSUyQiUyRnE2TFAlMkZ0OHZuWDMzbjRybWZpcEQlMkJqekNrTW8zc2slMkJQRzFxUjVjSDdkSGclM0QlM0Q; __gads=ID=94c05f8311e4d248:T=1639438008:S=ALNI_MYbuiZUrEu1eVL7SPcxwGVwNJ9qkA',
}

results = requests.get(url, headers=headers)

soup = BeautifulSoup(results.text,'html.parser')

parent_div = soup.findAll('div',{'class':'card-section'})

print(parent_div)
# Out:
# [<div class="card-section">
# <img alt="perfume Coco Mademoiselle" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.611.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Chanel/Coco-Mademoiselle-611.html"> Chanel Coco Mademoiselle
# <span aria-label="Link to Chanel Coco Mademoiselle female 2001" class="link-span" title="Chanel Coco Mademoiselle female 2001"></span></a></p>
# </div>, <div class="card-section">
# <img alt="perfume La Nuit de l'Homme" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.5521.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Yves-Saint-Laurent/La-Nuit-de-l-Homme-5521.html"> Yves Saint Laurent La Nuit de l'Homme
# <span aria-label="Link to Yves Saint Laurent La Nuit de l'Homme male 2009" class="link-span" title="Yves Saint Laurent La Nuit de l'Homme male 2009"></span></a></p>
# </div>, <div class="card-section">
# ...

# %%
  #1940-1949 https://www.fragrantica.com/search/?godina=1940%3A1949

import requests
from bs4 import BeautifulSoup

url = 'https://www.fragrantica.com/search/?godina=1940%3A1949'

headers = {
    'authority': 'www.fragrantica.com',
    'cache-control': 'max-age=0',
    'sec-ch-ua': '"Chromium";v="94", "Google Chrome";v="94", ";Not A Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Chrome OS"',
    'dnt': '1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 14150.87.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.124 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'referer': 'https://colab.research.google.com/',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': '__auc=0bc2fd9a17cdd73ef4db3b0e514; set_invisible=visible; _gid=GA1.2.260011367.1639937338; frecently=a%3A1%3A%7Bi%3A28711%3Bi%3A1639954575%3B%7D; __asc=e4e5971d17dd92457d9871a12a8; __cf_bm=dntSAPXrfV.Jx61fej9l5YVno_Tc6CeGO9RKgOt1vRI-1640026596-0-AYOujfbX9rb3EWUDf3bOgB6xuMG1SgDO5pOXjRiE48HvZ60uJR3YEWMhE5EoBrErr5jFejfCOsrxTJ4y8wqvKCzQkh91YSbGYmUM7O27JjsthCiPHGsPhYods5NP2BYMUg==; fragrantica_com_555=MTQwODk0N3w5MmM4ZGY4MzAwMmUyZjQ1ZGE2MTExZmE2YmNiZjVlZGU3M2ZlMmZhfDE2NDEyMzY0OTR8YzFmNmQxOGUyMWQ1MDQ5YjM2OTIyZjBhMDcyOTFiYzFiMTA2MDA5NA%3D%3D; rtyt45gh=19; _ga_LKTF6586LY=GS1.1.1640025572.13.1.1640026897.0; _ga=GA1.2.420026503.1639438000; cto_bundle=AA7ZB19hdWRqSWxTM3VvZVQwNWhUTFg2alJpbUthN1g0NzRaMzBOeTg4Y01OOEV0QVZWQ0R1b0ZaQSUyRnNvMmpuQmdta0EyNUpVZVVDUHdUUUZWNXZ4U1dJYUVsS01TcmhSRXlKYlF4MEtkY3RLcTRZcjJzQW1rR0tQUWI1eU91eFV4R2NnVnNEZ3dtVG5FeTBwc3VPWkNuQVkydyUzRCUzRA; __gads=ID=94c05f8311e4d248:T=1639438008:S=ALNI_MYbuiZUrEu1eVL7SPcxwGVwNJ9qkA',
}

results = requests.get(url, headers=headers)

soup = BeautifulSoup(results.text,'html.parser')

parent_div = soup.findAll('div',{'class':'card-section'})

print(parent_div)
# Out:
# [<div class="card-section">
# <img alt="perfume Coco Mademoiselle" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.611.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Chanel/Coco-Mademoiselle-611.html"> Chanel Coco Mademoiselle
# <span aria-label="Link to Chanel Coco Mademoiselle female 2001" class="link-span" title="Chanel Coco Mademoiselle female 2001"></span></a></p>
# </div>, <div class="card-section">
# <img alt="perfume La Nuit de l'Homme" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.5521.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Yves-Saint-Laurent/La-Nuit-de-l-Homme-5521.html"> Yves Saint Laurent La Nuit de l'Homme
# <span aria-label="Link to Yves Saint Laurent La Nuit de l'Homme male 2009" class="link-span" title="Yves Saint Laurent La Nuit de l'Homme male 2009"></span></a></p>
# </div>, <div class="card-section">
# ...

# %%
  #1950-1959 https://www.fragrantica.com/search/?godina=1950%3A1959

import requests
from bs4 import BeautifulSoup

url = 'https://www.fragrantica.com/search/?godina=1950%3A1959'

headers = {
    'authority': 'www.fragrantica.com',
    'cache-control': 'max-age=0',
    'sec-ch-ua': '"Chromium";v="94", "Google Chrome";v="94", ";Not A Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Chrome OS"',
    'dnt': '1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 14150.87.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.124 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'referer': 'https://colab.research.google.com/',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': '__auc=0bc2fd9a17cdd73ef4db3b0e514; set_invisible=visible; _gid=GA1.2.260011367.1639937338; frecently=a%3A1%3A%7Bi%3A28711%3Bi%3A1639954575%3B%7D; __asc=e4e5971d17dd92457d9871a12a8; __cf_bm=dntSAPXrfV.Jx61fej9l5YVno_Tc6CeGO9RKgOt1vRI-1640026596-0-AYOujfbX9rb3EWUDf3bOgB6xuMG1SgDO5pOXjRiE48HvZ60uJR3YEWMhE5EoBrErr5jFejfCOsrxTJ4y8wqvKCzQkh91YSbGYmUM7O27JjsthCiPHGsPhYods5NP2BYMUg==; fragrantica_com_555=MTQwODk0N3w5MmM4ZGY4MzAwMmUyZjQ1ZGE2MTExZmE2YmNiZjVlZGU3M2ZlMmZhfDE2NDEyMzY5NTN8OWU2ODNlMTExYjdmN2ViMzkzYjhmMWY2OGFlMTcwNThlNDI4NTFjNA%3D%3D; rtyt45gh=21; _ga_LKTF6586LY=GS1.1.1640025572.13.1.1640027358.0; _ga=GA1.2.420026503.1639438000; _gat_gtag_UA_1340700_3=1; cto_bundle=TccWb19hdWRqSWxTM3VvZVQwNWhUTFg2alJrT09xZ3d3OUxwSkdVR3N4dG0zOG1aTDdKd2lnODNRamN5MElMdk8zbFBka3pOSThWbjZmOFdsV2xzVWlGUVFEY3BLWTFidU9kY1AzSDVvdkZHY0RMMjZlR2l3Z2JnYTd0eHBBNU5hUVRMVzZTaFZzT01NUFJJNHJXR0xDZDlZSnclM0QlM0Q; __gads=ID=94c05f8311e4d248:T=1639438008:S=ALNI_MYbuiZUrEu1eVL7SPcxwGVwNJ9qkA',
}

results = requests.get(url, headers=headers)

soup = BeautifulSoup(results.text,'html.parser')

parent_div = soup.findAll('div',{'class':'card-section'})

print(parent_div)
# Out:
# [<div class="card-section">
# <img alt="perfume Coco Mademoiselle" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.611.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Chanel/Coco-Mademoiselle-611.html"> Chanel Coco Mademoiselle
# <span aria-label="Link to Chanel Coco Mademoiselle female 2001" class="link-span" title="Chanel Coco Mademoiselle female 2001"></span></a></p>
# </div>, <div class="card-section">
# <img alt="perfume La Nuit de l'Homme" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.5521.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Yves-Saint-Laurent/La-Nuit-de-l-Homme-5521.html"> Yves Saint Laurent La Nuit de l'Homme
# <span aria-label="Link to Yves Saint Laurent La Nuit de l'Homme male 2009" class="link-span" title="Yves Saint Laurent La Nuit de l'Homme male 2009"></span></a></p>
# </div>, <div class="card-section">
# ...

# %%
  #1960-1969 https://www.fragrantica.com/search/?godina=1960%3A1969

import requests
from bs4 import BeautifulSoup

url = 'https://www.fragrantica.com/search/?godina=1960%3A1969'

headers = {
    'authority': 'www.fragrantica.com',
    'cache-control': 'max-age=0',
    'sec-ch-ua': '"Chromium";v="94", "Google Chrome";v="94", ";Not A Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Chrome OS"',
    'dnt': '1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 14150.87.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.124 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'referer': 'https://colab.research.google.com/',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': '__auc=0bc2fd9a17cdd73ef4db3b0e514; set_invisible=visible; _gid=GA1.2.260011367.1639937338; frecently=a%3A1%3A%7Bi%3A28711%3Bi%3A1639954575%3B%7D; __asc=e4e5971d17dd92457d9871a12a8; __cf_bm=anhR.HqlEj4kzcZqkbLbKlAWc1_mvZavCINplQ0Xd0M-1640028473-0-AfzLsr7Kv0TUvxDtuz5bAR3pLEeHgpqXD1EYjJAcbaKR+W3Fk01M7WGR102PkX5sw29B/H50GK1V1fV8GcLuJalkSxoi49rbWwvfWtDTEARAKKIH8fuNerjxj/USN0p7cg==; fragrantica_com_555=MTQwODk0N3w5MmM4ZGY4MzAwMmUyZjQ1ZGE2MTExZmE2YmNiZjVlZGU3M2ZlMmZhfDE2NDEyMzgzMTh8NDIwYTY2MDQ2YzQzNzE1NzcwZTg1N2Y2NmEwNjgyOTg2MDI5Mjk2OA%3D%3D; rtyt45gh=25; _ga_LKTF6586LY=GS1.1.1640025572.13.1.1640028720.0; _ga=GA1.2.420026503.1639438000; _gat_gtag_UA_1340700_3=1; cto_bundle=KbmNC19hdWRqSWxTM3VvZVQwNWhUTFg2alJ1UVhTJTJCSXdBJTJGRk1aMWl3YjhOS29IUGVsTFNoSXYlMkJLYllrRyUyRkdUYXRTNm9iRFolMkJVOFZPWHU5M0R0dmdxVjBjJTJGWm81UzdFN1FDc0FoOXI3NUFjcE1HbjR3WHh0TzJXd281eEdpajlPJTJCTnhxZXNseVJMOWZBMFJrRkRlJTJCaUwzSEdBJTNEJTNE; __gads=ID=94c05f8311e4d248:T=1639438008:S=ALNI_MYbuiZUrEu1eVL7SPcxwGVwNJ9qkA',
}

results = requests.get(url, headers=headers)

soup = BeautifulSoup(results.text,'html.parser')

parent_div = soup.findAll('div',{'class':'card-section'})

print(parent_div)
# Out:
# [<div class="card-section">
# <img alt="perfume Coco Mademoiselle" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.611.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Chanel/Coco-Mademoiselle-611.html"> Chanel Coco Mademoiselle
# <span aria-label="Link to Chanel Coco Mademoiselle female 2001" class="link-span" title="Chanel Coco Mademoiselle female 2001"></span></a></p>
# </div>, <div class="card-section">
# <img alt="perfume La Nuit de l'Homme" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.5521.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Yves-Saint-Laurent/La-Nuit-de-l-Homme-5521.html"> Yves Saint Laurent La Nuit de l'Homme
# <span aria-label="Link to Yves Saint Laurent La Nuit de l'Homme male 2009" class="link-span" title="Yves Saint Laurent La Nuit de l'Homme male 2009"></span></a></p>
# </div>, <div class="card-section">
# ...

# %%
  #1970-1979 https://www.fragrantica.com/search/?godina=1970%3A1979

import requests
from bs4 import BeautifulSoup

url = 'https://www.fragrantica.com/search/?godina=1920%3A1929'

headers = {
    'authority': 'csm.us.criteo.net',
    'sec-ch-ua': '"Chromium";v="94", "Google Chrome";v="94", ";Not A Brand";v="99"',
    'dnt': '1',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 14150.87.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.124 Safari/537.36',
    'sec-ch-ua-platform': '"Chrome OS"',
    'content-type': 'text/plain;charset=UTF-8',
    'accept': '*/*',
    'origin': 'https://ads.us.criteo.com',
    'sec-fetch-site': 'cross-site',
    'sec-fetch-mode': 'no-cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://ads.us.criteo.com/',
    'accept-language': 'en-US,en;q=0.9',
}

results = requests.get(url, headers=headers)

soup = BeautifulSoup(results.text,'html.parser')

parent_div = soup.findAll('div',{'class':'card-section'})

print(parent_div)

# %%
  #1980-1989 https://www.fragrantica.com/search/?godina=1980%3A1989

import requests
from bs4 import BeautifulSoup

url = 'https://www.fragrantica.com/search/?godina=1980%3A1989'

headers = {
    'authority': 'csm.us.criteo.net',
    'sec-ch-ua': '"Chromium";v="94", "Google Chrome";v="94", ";Not A Brand";v="99"',
    'dnt': '1',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 14150.87.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.124 Safari/537.36',
    'sec-ch-ua-platform': '"Chrome OS"',
    'content-type': 'text/plain;charset=UTF-8',
    'accept': '*/*',
    'origin': 'https://ads.us.criteo.com',
    'sec-fetch-site': 'cross-site',
    'sec-fetch-mode': 'no-cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://ads.us.criteo.com/',
    'accept-language': 'en-US,en;q=0.9',
}

results = requests.get(url, headers=headers)

soup = BeautifulSoup(results.text,'html.parser')

parent_div = soup.findAll('div',{'class':'card-section'})

print(parent_div)

# %%
  #1990-1999 https://www.fragrantica.com/search/?godina=1990%3A1999

import requests
from bs4 import BeautifulSoup

url = 'https://www.fragrantica.com/search/?godina=1990%3A1999'

headers = {
    'authority': 'www.fragrantica.com',
    'cache-control': 'max-age=0',
    'sec-ch-ua': '"Chromium";v="94", "Google Chrome";v="94", ";Not A Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Chrome OS"',
    'dnt': '1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 14150.87.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.124 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'referer': 'https://colab.research.google.com/',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': '__auc=0bc2fd9a17cdd73ef4db3b0e514; set_invisible=visible; _gid=GA1.2.260011367.1639937338; frecently=a%3A1%3A%7Bi%3A28711%3Bi%3A1639954575%3B%7D; __asc=e4e5971d17dd92457d9871a12a8; __cf_bm=anhR.HqlEj4kzcZqkbLbKlAWc1_mvZavCINplQ0Xd0M-1640028473-0-AfzLsr7Kv0TUvxDtuz5bAR3pLEeHgpqXD1EYjJAcbaKR+W3Fk01M7WGR102PkX5sw29B/H50GK1V1fV8GcLuJalkSxoi49rbWwvfWtDTEARAKKIH8fuNerjxj/USN0p7cg==; fragrantica_com_555=MTQwODk0N3w5MmM4ZGY4MzAwMmUyZjQ1ZGE2MTExZmE2YmNiZjVlZGU3M2ZlMmZhfDE2NDEyMzg3NDh8OTJiOTU1ZmIzZGRhOGE2ODI3YmJmZmEwZjk0ZGY1NzQzMDQ1ZTAyMA%3D%3D; rtyt45gh=27; _ga_LKTF6586LY=GS1.1.1640025572.13.1.1640029151.0; _ga=GA1.2.420026503.1639438000; cto_bundle=ySyYpV9hdWRqSWxTM3VvZVQwNWhUTFg2alJuV2J2R2gzT1VoZmhxNGVoc3NpOXlLWmd2cXBSTlF6c0VEJTJGb1Zzb3FWZ3VkZyUyRjY4ek8lMkJNenZYJTJCJTJGNm92bDdqZXBpV1UzbVFXeEN1Z3JGaEh6Njd2eVd0QnVNdTFvcUFmdHlTakJVTnpWYURyMjBoNDVCcGFyb0VtVnI4VmNxUTBRJTNEJTNE; __gads=ID=94c05f8311e4d248:T=1639438008:S=ALNI_MYbuiZUrEu1eVL7SPcxwGVwNJ9qkA',
}

results = requests.get(url, headers=headers)

soup = BeautifulSoup(results.text,'html.parser')

parent_div = soup.findAll('div',{'class':'card-section'})

print(parent_div)
# Out:
# [<div class="card-section">
# <img alt="perfume Coco Mademoiselle" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.611.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Chanel/Coco-Mademoiselle-611.html"> Chanel Coco Mademoiselle
# <span aria-label="Link to Chanel Coco Mademoiselle female 2001" class="link-span" title="Chanel Coco Mademoiselle female 2001"></span></a></p>
# </div>, <div class="card-section">
# <img alt="perfume La Nuit de l'Homme" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.5521.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Yves-Saint-Laurent/La-Nuit-de-l-Homme-5521.html"> Yves Saint Laurent La Nuit de l'Homme
# <span aria-label="Link to Yves Saint Laurent La Nuit de l'Homme male 2009" class="link-span" title="Yves Saint Laurent La Nuit de l'Homme male 2009"></span></a></p>
# </div>, <div class="card-section">
# ...

# %%
  #2000-2009 https://www.fragrantica.com/search/?godina=2000%3A2009

import requests
from bs4 import BeautifulSoup

url = 'https://www.fragrantica.com/search/?godina=2000%3A2009'

headers = {
    'authority': 'www.fragrantica.com',
    'cache-control': 'max-age=0',
    'sec-ch-ua': '"Chromium";v="94", "Google Chrome";v="94", ";Not A Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Chrome OS"',
    'dnt': '1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 14150.87.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.124 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'referer': 'https://colab.research.google.com/',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': '__auc=0bc2fd9a17cdd73ef4db3b0e514; set_invisible=visible; _gid=GA1.2.260011367.1639937338; frecently=a%3A1%3A%7Bi%3A28711%3Bi%3A1639954575%3B%7D; __asc=e4e5971d17dd92457d9871a12a8; fragrantica_com_555=MTQwODk0N3w5MmM4ZGY4MzAwMmUyZjQ1ZGE2MTExZmE2YmNiZjVlZGU3M2ZlMmZhfDE2NDEyMzkwNTV8MDA3OWNhOGVmNGM3NDE4ZDUwNmZjZDBmMGQzYTcwMzVkM2JjNGI1Mg%3D%3D; rtyt45gh=29; __cf_bm=wynDxLYucChS.DhU.XcqpglzHHMvOdhqvPLum9LVTtU-1640029458-0-AZ42hWybs5VssFsovAZtjl4uzhTnrmBqpeJsukpT1JfKoMxbG5IEFO4tPhzuyKDKAi/wucagmndQKL6R8UtBJDBpxEqO8uZ0evOGRzSg63hPQR7VMe1Vo8OIBcZsl/+jdw==; _ga_LKTF6586LY=GS1.1.1640025572.13.1.1640029459.0; _ga=GA1.2.420026503.1639438000; cto_bundle=f-nSw19hdWRqSWxTM3VvZVQwNWhUTFg2alJteXZaQ2loeEt2cFdEb3BWZUJjYWhZbWFObkdRUXBKRVZQMHFwMzNqOU5waG8wVktieUZvSjVjVk56c252JTJCc3J5VTZKUWtBJTJCTiUyQklMT3d5cHBQQ2YydyUyRmIlMkZXMDVITnBvcXJnYzVHVlZlYWVGbTJoNUxhNGdGbyUyQnN0akRJQ3hzYXclM0QlM0Q; __gads=ID=94c05f8311e4d248:T=1639438008:S=ALNI_MYbuiZUrEu1eVL7SPcxwGVwNJ9qkA',
}

results = requests.get(url, headers=headers)

soup = BeautifulSoup(results.text,'html.parser')

parent_div = soup.findAll('div',{'class':'card-section'})

print(parent_div)
# Out:
# [<div class="card-section">
# <img alt="perfume Coco Mademoiselle" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.611.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Chanel/Coco-Mademoiselle-611.html"> Chanel Coco Mademoiselle
# <span aria-label="Link to Chanel Coco Mademoiselle female 2001" class="link-span" title="Chanel Coco Mademoiselle female 2001"></span></a></p>
# </div>, <div class="card-section">
# <img alt="perfume La Nuit de l'Homme" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.5521.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Yves-Saint-Laurent/La-Nuit-de-l-Homme-5521.html"> Yves Saint Laurent La Nuit de l'Homme
# <span aria-label="Link to Yves Saint Laurent La Nuit de l'Homme male 2009" class="link-span" title="Yves Saint Laurent La Nuit de l'Homme male 2009"></span></a></p>
# </div>, <div class="card-section">
# ...

# %%
  #2010-2019 https://www.fragrantica.com/search/?godina=2010%3A2019

import requests
from bs4 import BeautifulSoup

url = 'https://www.fragrantica.com/search/?godina=2010%3A2019'

headers = {
    'authority': 'www.fragrantica.com',
    'cache-control': 'max-age=0',
    'sec-ch-ua': '"Chromium";v="94", "Google Chrome";v="94", ";Not A Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Chrome OS"',
    'dnt': '1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 14150.87.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.124 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'referer': 'https://colab.research.google.com/',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': '__auc=0bc2fd9a17cdd73ef4db3b0e514; set_invisible=visible; _gid=GA1.2.260011367.1639937338; frecently=a%3A1%3A%7Bi%3A28711%3Bi%3A1639954575%3B%7D; __asc=e4e5971d17dd92457d9871a12a8; __cf_bm=wynDxLYucChS.DhU.XcqpglzHHMvOdhqvPLum9LVTtU-1640029458-0-AZ42hWybs5VssFsovAZtjl4uzhTnrmBqpeJsukpT1JfKoMxbG5IEFO4tPhzuyKDKAi/wucagmndQKL6R8UtBJDBpxEqO8uZ0evOGRzSg63hPQR7VMe1Vo8OIBcZsl/+jdw==; fragrantica_com_555=MTQwODk0N3w5MmM4ZGY4MzAwMmUyZjQ1ZGE2MTExZmE2YmNiZjVlZGU3M2ZlMmZhfDE2NDEyMzk1NzB8ZWZkNjA4YjIwYzBiNjQzNDA4ZTk3Njc2ZjA0NjZlM2NmMjc3YjBjNg%3D%3D; rtyt45gh=31; _ga_LKTF6586LY=GS1.1.1640025572.13.1.1640029973.0; _ga=GA1.2.420026503.1639438000; cto_bundle=8Auq0V9hdWRqSWxTM3VvZVQwNWhUTFg2alJ0cENjMHBYZXl1cEdTNXVtdDh4YVhxZU1pUDlzSjl0RFAlMkZyY3N3R0ZBRXM5cWlkZGFnV1hZT1IwaEJmTlhqc2F4QzF5aVVNJTJGT0xPcEh5aDVES3BNUHlLNlNKbHEyZ0MwRDRBUWxONmJOcEJ2Z1ZLWjdSdUphUE12b3I4cFQwTDR3JTNEJTNE; __gads=ID=94c05f8311e4d248:T=1639438008:S=ALNI_MYbuiZUrEu1eVL7SPcxwGVwNJ9qkA',
}

results = requests.get(url, headers=headers)

soup = BeautifulSoup(results.text,'html.parser')

parent_div = soup.findAll('div',{'class':'card-section'})

print(parent_div)
# Out:
# [<div class="card-section">
# <img alt="perfume Coco Mademoiselle" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.611.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Chanel/Coco-Mademoiselle-611.html"> Chanel Coco Mademoiselle
# <span aria-label="Link to Chanel Coco Mademoiselle female 2001" class="link-span" title="Chanel Coco Mademoiselle female 2001"></span></a></p>
# </div>, <div class="card-section">
# <img alt="perfume La Nuit de l'Homme" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.5521.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Yves-Saint-Laurent/La-Nuit-de-l-Homme-5521.html"> Yves Saint Laurent La Nuit de l'Homme
# <span aria-label="Link to Yves Saint Laurent La Nuit de l'Homme male 2009" class="link-span" title="Yves Saint Laurent La Nuit de l'Homme male 2009"></span></a></p>
# </div>, <div class="card-section">
# ...

# %%
  #2020-2021 https://www.fragrantica.com/search/?godina=2020%3A2021

import requests
from bs4 import BeautifulSoup

url = 'https://www.fragrantica.com/search/?godina=2020%3A2021'

headers = {
    'authority': 'www.fragrantica.com',
    'cache-control': 'max-age=0',
    'sec-ch-ua': '"Chromium";v="94", "Google Chrome";v="94", ";Not A Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Chrome OS"',
    'dnt': '1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 14150.87.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.124 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'referer': 'https://colab.research.google.com/',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': '__auc=0bc2fd9a17cdd73ef4db3b0e514; set_invisible=visible; _gid=GA1.2.260011367.1639937338; frecently=a%3A1%3A%7Bi%3A28711%3Bi%3A1639954575%3B%7D; __asc=e4e5971d17dd92457d9871a12a8; __cf_bm=wynDxLYucChS.DhU.XcqpglzHHMvOdhqvPLum9LVTtU-1640029458-0-AZ42hWybs5VssFsovAZtjl4uzhTnrmBqpeJsukpT1JfKoMxbG5IEFO4tPhzuyKDKAi/wucagmndQKL6R8UtBJDBpxEqO8uZ0evOGRzSg63hPQR7VMe1Vo8OIBcZsl/+jdw==; fragrantica_com_555=MTQwODk0N3w5MmM4ZGY4MzAwMmUyZjQ1ZGE2MTExZmE2YmNiZjVlZGU3M2ZlMmZhfDE2NDEyMzk3OTZ8ZTVkOTdkYmRmODg4ZDIyNzBkYzU1Y2U4ZGQ5Zjg4ZTIzNjE0MWJkMQ%3D%3D; rtyt45gh=33; _ga_LKTF6586LY=GS1.1.1640025572.13.1.1640030198.0; _ga=GA1.2.420026503.1639438000; _gat_gtag_UA_1340700_3=1; cto_bundle=IrFeNV9hdWRqSWxTM3VvZVQwNWhUTFg2alJ0clNjZ2tkT3NKMGRHUGlhSSUyQlE1eiUyRnFiQlJVSlNGNThROXhjUiUyQjFqNTZOTzVOWE83VU0yNFNpaHdMMnQxVGRGT0hVJTJGcUVuZVlQeXRkZ1VaeTAlMkJxYTM2YTI3dXh0WENtdVNjNlQ2V29KdkpMUDUwJTJCQnRzVVMlMkIlMkJpVWpJNTVsaWRRJTNEJTNE; __gads=ID=94c05f8311e4d248:T=1639438008:S=ALNI_MYbuiZUrEu1eVL7SPcxwGVwNJ9qkA',
}

results = requests.get(url, headers=headers)

soup = BeautifulSoup(results.text,'html.parser')

parent_div = soup.findAll('div',{'class':'card-section'})

print(parent_div)
# Out:
# [<div class="card-section">
# <img alt="perfume Coco Mademoiselle" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.611.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Chanel/Coco-Mademoiselle-611.html"> Chanel Coco Mademoiselle
# <span aria-label="Link to Chanel Coco Mademoiselle female 2001" class="link-span" title="Chanel Coco Mademoiselle female 2001"></span></a></p>
# </div>, <div class="card-section">
# <img alt="perfume La Nuit de l'Homme" height="85" loading="lazy" src="https://fimgs.net/mdimg/perfume/m.5521.jpg" width="75">
# </img></div>, <div class="card-section">
# <p><a href="/perfume/Yves-Saint-Laurent/La-Nuit-de-l-Homme-5521.html"> Yves Saint Laurent La Nuit de l'Homme
# <span aria-label="Link to Yves Saint Laurent La Nuit de l'Homme male 2009" class="link-span" title="Yves Saint Laurent La Nuit de l'Homme male 2009"></span></a></p>
# </div>, <div class="card-section">
# ...
